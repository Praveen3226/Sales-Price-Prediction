# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\viper\Desktop\NOTES\AI_ML_DS\Projects\Beverages_price\synthetic_beverage_sales_data.csv")

# %%
df
# Out:
#            Order_ID Customer_ID Customer_Type              Product  \
# 0              ORD1     CUS1496           B2B           Vio Wasser
# 1              ORD1     CUS1496           B2B                Evian
# 2              ORD1     CUS1496           B2B               Sprite
# 3              ORD1     CUS1496           B2B   Rauch Multivitamin
# 4              ORD1     CUS1496           B2B         Gerolsteiner
# ...             ...         ...           ...                  ...
# 8999905  ORD2999999     CUS7080           B2C        Schwip Schwap
# 8999906  ORD2999999     CUS7080           B2C       San Pellegrino
# 8999907  ORD3000000     CUS6551           B2B             Red Bull
# 8999908  ORD3000000     CUS6551           B2B  Passion Fruit Juice
# 8999909  ORD3000000     CUS6551           B2B               Vittel
#
#             Category  Unit_Price  Quantity  Discount  Total_Price  \
# 0              Water        1.66        53      0.10        79.18
# ...

# %%
df.shape
# Out:
# (8999910, 11)

# %%
df.head()
# Out:
#   Order_ID Customer_ID Customer_Type             Product     Category  \
# 0     ORD1     CUS1496           B2B          Vio Wasser        Water
# 1     ORD1     CUS1496           B2B               Evian        Water
# 2     ORD1     CUS1496           B2B              Sprite  Soft Drinks
# 3     ORD1     CUS1496           B2B  Rauch Multivitamin       Juices
# 4     ORD1     CUS1496           B2B        Gerolsteiner        Water
#
#    Unit_Price  Quantity  Discount  Total_Price             Region  Order_Date
# 0        1.66        53      0.10        79.18  Baden-Württemberg  2023-08-23
# 1        1.56        90      0.10       126.36  Baden-Württemberg  2023-08-23
# 2        1.17        73      0.05        81.14  Baden-Württemberg  2023-08-23
# 3        3.22        59      0.10       170.98  Baden-Württemberg  2023-08-23
# 4        0.87        35      0.10        27.40  Baden-Württemberg  2023-08-23

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Customer_Type    0
# Product          0
# Category         0
# Unit_Price       0
# Quantity         0
# Discount         0
# Total_Price      0
# Region           0
# Order_Date       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le=(df["beverage_category"])=le.fit_transform(df["Category"])

# %%
le=(df["product_cat"])=le.fit_transform(df["Product"])

# %%
le=(df["customer_cat"])=le.fit_transform(df["Customer_Type"])

# %%
le=(df["region_cat"])=le.fit_transform(df["Region"])

# %%
le
# Out:
# array([ 0,  0,  0, ..., 13, 13, 13], shape=(8999910,))

# %%
df
# Out:
#            Order_ID Customer_ID Customer_Type              Product  \
# 0              ORD1     CUS1496           B2B           Vio Wasser
# 1              ORD1     CUS1496           B2B                Evian
# 2              ORD1     CUS1496           B2B               Sprite
# 3              ORD1     CUS1496           B2B   Rauch Multivitamin
# 4              ORD1     CUS1496           B2B         Gerolsteiner
# ...             ...         ...           ...                  ...
# 8999905  ORD2999999     CUS7080           B2C        Schwip Schwap
# 8999906  ORD2999999     CUS7080           B2C       San Pellegrino
# 8999907  ORD3000000     CUS6551           B2B             Red Bull
# 8999908  ORD3000000     CUS6551           B2B  Passion Fruit Juice
# 8999909  ORD3000000     CUS6551           B2B               Vittel
#
#             Category  Unit_Price  Quantity  Discount  Total_Price  \
# 0              Water        1.66        53      0.10        79.18
# ...

# %%
x=df[["beverage_category","product_cat","customer_cat","region_cat","Unit_Price","Quantity","Discount"]]
y=df["Total_Price"]

# %%
from sklearn.linear_model import LinearRegression

# %%
mdl=LinearRegression()

# %%
mdl.fit(x,y)
# Out:
# LinearRegression()

# %%
df[["Total_Price","beverage_category","product_cat","customer_cat","region_cat","Unit_Price","Quantity","Discount","Customer_Type","Product","Category","Region"]]
# Out:
#          Total_Price  beverage_category  product_cat  customer_cat  \
# 0              79.18                  3           42             0
# 1             126.36                  3            9             0
# 2              81.14                  2           38             0
# 3             170.98                  1           29             0
# 4              27.40                  3           12             0
# ...              ...                ...          ...           ...
# 8999905         2.54                  2           36             1
# 8999906        13.65                  3           34             1
# 8999907       169.34                  2           30             0
# 8999908       287.24                  1           27             0
# 8999909         3.08                  3           43             0
#
#          region_cat  Unit_Price  Quantity  Discount Customer_Type  \
# 0                 0        1.66        53      0.10           B2B
# ...

# %% [markdown]
# x=df[["beverage_category","product_cat","customer_cat","region_cat","Unit_Price","Quantity","Discount"]]
# y=df["Total_Price"]

# %%
mdl.predict([[3,42,0,0,1.66,53,0.10]])
# Out:
# C:\Users\viper\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([195.19894076])

# %%
actual_price=df["Total_Price"]==126.36

# %%
mdl.predict([[3,9,0,0,1.56,90,0.10]])
# Out:
# C:\Users\viper\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([426.13653433])

# %%
ls=abs(actual_price-(mdl.predict([[3,9,0,0,1.56,90,0.10]])))
# Out:
# C:\Users\viper\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
ls[0]
# Out:
# np.float64(426.1365343281351)

# %%
import joblib

# %%
dump=joblib.dump(mdl,r"C:\Users\viper\Desktop\NOTES\AI_ML_DS\Projects\Beverages_price\beverages_price.pkl")

# %%
df.Category.unique()
# Out:
# array(['Water', 'Soft Drinks', 'Juices', 'Alcoholic Beverages'],
#       dtype=object)

# %%
df.Customer_Type.unique()
# Out:
# array(['B2B', 'B2C'], dtype=object)

# %%
df.Product.unique()
# Out:
# array(['Vio Wasser', 'Evian', 'Sprite', 'Rauch Multivitamin',
#        'Gerolsteiner', 'Sauvignon Blanc', 'Tomato Juice', 'Vittel',
#        'San Pellegrino', 'Mountain Dew', 'Hohes C Orange', 'Red Bull',
#        'Chardonnay', 'Tanqueray', 'Rotkäppchen Sekt', 'Mango Juice',
#        'Apollinaris', 'Riesling', 'Granini Apple', 'Fanta', 'Rockstar',
#        'Club Mate', 'Krombacher', 'Erdinger Weißbier', 'Volvic Touch',
#        'Volvic', 'Schwip Schwap', 'Fritz-Kola', 'Coca-Cola', 'Selters',
#        'Cranberry Juice', 'Mezzo Mix', "Beck's", 'Passion Fruit Juice',
#        'Monster', 'Augustiner', 'Pepsi', 'Merlot', 'Kölsch', 'Bacardi',
#        'Warsteiner', 'Moët & Chandon', 'Jever', 'Veuve Clicquot',
#        'Johnnie Walker', 'Havana Club', 'Jack Daniels'], dtype=object)

# %%
df.Region.unique()
# Out:
# array(['Baden-Württemberg', 'Schleswig-Holstein', 'Hamburg', 'Bayern',
#        'Saarland', 'Thüringen', 'Brandenburg', 'Nordrhein-Westfalen',
#        'Mecklenburg-Vorpommern', 'Sachsen-Anhalt', 'Niedersachsen',
#        'Rheinland-Pfalz', 'Bremen', 'Sachsen', 'Hessen', 'Berlin'],
#       dtype=object)
